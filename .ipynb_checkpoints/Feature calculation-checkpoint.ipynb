# %% [markdown]
# # We are going to calculate features based on sliding windows

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hop: overlap= 1.5 seconnds <br>
# Window_size= 3 seconds <br>
# On each window we are going to calculate statistical features and frequency based features
# - median
# - std
# - skew
# - kurt
# - SMA
# - energy
# - mean absolute deviation
# - rms
# - minimum
# - maximum
# - MCR
# - max_freq
# - max_freq_val
# - dom_freq_ratio
# - spectral_flatness
# - spectral entropy estimate

# %%
from feature_calculations import *
#we code together :(
